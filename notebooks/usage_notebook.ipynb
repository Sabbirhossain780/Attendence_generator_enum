# %% [markdown]
# ## Attendance Sheet Generator
# **BRAC Institute of Governance and Development**
#
# Run the cells below in order:
# 1. **Cell 2** — installs / updates the tool (safe to run every time)
# 2. **Cell 3** — opens the setup form; fill it in and click **Generate**

# %%
# Install or upgrade to the latest version
import subprocess, sys
result = subprocess.run(
    [sys.executable, "-m", "pip", "install", "--upgrade", "--quiet",
     "git+https://github.com/Sabbirhossain780/attendance-generator.git"],
    capture_output=True, text=True
)
if result.returncode == 0:
    print("✓ attendance-generator is up to date.")
else:
    print("✗ Installation failed:")
    print(result.stderr)

# %%
from attendance_generator import run_wizard
run_wizard()
